# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
files = os.path.join("../Raw Data/Airport Data/flight_data_*.csv")
# list of merged files returned
files = glob.glob(files)

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df
# Out:
#           YEAR  MONTH  DAY_OF_WEEK                FL_DATE BRANDED_CODE_SHARE  \
# 0         2018      1            1  1/22/2018 12:00:00 AM                 UA
# 1         2018      1            1  1/22/2018 12:00:00 AM                 UA
# 2         2018      1            1  1/22/2018 12:00:00 AM                 UA
# 3         2018      1            1  1/22/2018 12:00:00 AM                 UA
# 4         2018      1            1  1/22/2018 12:00:00 AM                 UA
# ...        ...    ...          ...                    ...                ...
# 26789690  2022      3            4  3/24/2022 12:00:00 AM       AA_CODESHARE
# 26789691  2022      3            5  3/25/2022 12:00:00 AM       AA_CODESHARE
# 26789692  2022      3            7  3/27/2022 12:00:00 AM       AA_CODESHARE
# 26789693  2022      3            1  3/28/2022 12:00:00 AM       AA_CODESHARE
# 26789694  2022      3            2  3/29/2022 12:00:00 AM       AA_CODESHARE
#
# ...

# %%
# Feb 2019 data was missing so checking that it merged correctly
df.loc[df['FL_DATE'] == '2/2/2019 12:00:00 AM']
# Out:
#          YEAR  MONTH  DAY_OF_WEEK               FL_DATE BRANDED_CODE_SHARE  \
# 8356119  2019      2            6  2/2/2019 12:00:00 AM                 AA
# 8356147  2019      2            6  2/2/2019 12:00:00 AM                 AA
# 8356172  2019      2            6  2/2/2019 12:00:00 AM                 AA
# 8356199  2019      2            6  2/2/2019 12:00:00 AM                 AA
# 8356227  2019      2            6  2/2/2019 12:00:00 AM                 AA
# ...       ...    ...          ...                   ...                ...
# 8902871  2019      2            6  2/2/2019 12:00:00 AM       AA_CODESHARE
# 8902875  2019      2            6  2/2/2019 12:00:00 AM       AA_CODESHARE
# 8902924  2019      2            6  2/2/2019 12:00:00 AM       AA_CODESHARE
# 8902976  2019      2            6  2/2/2019 12:00:00 AM       AA_CODESHARE
# 8903004  2019      2            6  2/2/2019 12:00:00 AM       AA_CODESHARE
#
#         ORIGIN DEST DEST_STATE_NM  CRS_DEP_TIME  DEP_TIME  ...  \
# ...

# %%
df.to_csv("Merged_Raw_Flight_Data.csv")
